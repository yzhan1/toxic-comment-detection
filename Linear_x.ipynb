# %%
#%load_ext nb_black

# %% [markdown]
# https://www.kaggle.com/jhoward/nb-svm-strong-linear-baseline

# %% [markdown]
# # Toxic Comment Classification

# %%
import re
import string

import nltk
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud, STOPWORDS
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from utils import data_loader

np.random.seed(0)

# %%
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to /Users/aiden/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/aiden/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
TRAIN_FILE = "data/train.csv"
TEST_FILE = "data/test.csv"
TEST_LABEL_FILE = "data/test_labels.csv"

# %%
train_df, valid_df = data_loader.load_train_data(TRAIN_FILE, valid_rate=0.25)
test_df = data_loader.load_test_data(TEST_FILE, TEST_LABEL_FILE)

# %% [markdown]
# ## Data Exploration

# %%
train_df.head()
# Out:
#                       id                                       comment_text  \
# 130060  b7bf5a6846bd456a  "\n Oppose. WP:MOSTM, the guideline covering t...
# 132921  c70efd55724be549            === I AM GLEN AND I LOVE BEING A FAG===
# 46589   7c7f688f129e511e  "\n\nIf it happens it may be worth noting but ...
# 129843  b68d08319e5fcb14        }}\n{{WikiProject Elections and Referendums
# 2528    06bf9f58011ca46a  "\n\nI posted a thread about Donny on WP:ANI  ...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 130060      0             0        0       0       0              0
# 132921      1             0        0       0       0              0
# 46589       0             0        0       0       0              0
# 129843      0             0        0       0       0              0
# 2528        0             0        0       0       0              0

# %%
valid_df.head()
# Out:
#                      id                                       comment_text  \
# 56041  95bf7672a11f2799  Risk factors\n\nThe role of chlamydia should b...
# 90055  f0f3d0b835e0caae  Re your reversion of the removal of the websit...
# 86260  e6b38969b6d30127  But I do hate the_pope and think he I'd a pomp...
# 30981  524b653cc3469fe8  "\nI am not interest in a Good Article ""revie...
# 8241   15e9e6b13c61af45  Hi again! I have added my image with appropria...
#
#        toxic  severe_toxic  obscene  threat  insult  identity_hate
# 56041      0             0        0       0       0              0
# 90055      0             0        0       0       0              0
# 86260      1             0        1       0       1              0
# 30981      0             0        0       0       0              0
# 8241       0             0        0       0       0              0

# %%
test_df.head()
# Out:
#                   id                                       comment_text  \
# 5   0001ea8717f6de06  Thank you for understanding. I think very high...
# 7   000247e83dcc1211                   :Dear god this site is horrible.
# 11  0002f87b16116a7f  "::: Somebody will invariably try to add Relig...
# 13  0003e1cccfd5a40a  " \n\n It says it right there that it IS a typ...
# 14  00059ace3e3e9a53  " \n\n == Before adding a new product to the l...
#
#     toxic  severe_toxic  obscene  threat  insult  identity_hate
# 5       0             0        0       0       0              0
# 7       0             0        0       0       0              0
# 11      0             0        0       0       0              0
# 13      0             0        0       0       0              0
# 14      0             0        0       0       0              0

# %%
COMMENT = "comment_text"
LABELS = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]

# %%
def strip_punctuations(s, replace=" "):
    s = s.translate(str.maketrans("", "", string.punctuation))
    return re.sub(r"\s+", replace, s)

# %%
train_df.head()
# Out:
#                       id                                       comment_text  \
# 130060  b7bf5a6846bd456a  "\n Oppose. WP:MOSTM, the guideline covering t...
# 132921  c70efd55724be549            === I AM GLEN AND I LOVE BEING A FAG===
# 46589   7c7f688f129e511e  "\n\nIf it happens it may be worth noting but ...
# 129843  b68d08319e5fcb14        }}\n{{WikiProject Elections and Referendums
# 2528    06bf9f58011ca46a  "\n\nI posted a thread about Donny on WP:ANI  ...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 130060      0             0        0       0       0              0
# 132921      1             0        0       0       0              0
# 46589       0             0        0       0       0              0
# 129843      0             0        0       0       0              0
# 2528        0             0        0       0       0              0

# %%
comment_lengths = train_df[COMMENT].str.len()
print("min length of comments: ", comment_lengths.min())
print("max length of comments: ", comment_lengths.max())
print("mean length of comments: ", comment_lengths.mean())
# Out:
# min length of comments:  6
# max length of comments:  5000
# mean length of comments:  393.94203492456427

# %%
comment_lengths.hist()

# %%
train_df.isnull().sum()
# Out:
# id               0
# comment_text     0
# toxic            0
# severe_toxic     0
# obscene          0
# threat           0
# insult           0
# identity_hate    0
# dtype: int64

# %% [markdown]
# ### Distributions of Different Labels

# %%
def show_column_distribution(labels):
    for label in labels:
        train_df[label].value_counts().plot.bar()
        plt.title("Distribution of %s comments" % label)
        plt.xlabel("Is %s" % label)
        plt.ylabel("Count")
        plt.show()


show_column_distribution(LABELS)

# %% [markdown]
# ### Relationship between "Toxic" and other labels

# %%
def find_toxic_percentage(labels):
    for label in labels:
        df = train_df[train_df[label] == 1]
        percentage = (df[df["toxic"] == 1].shape[0] / df.shape[0]) * 100
        print("%.2f %% of %s comments are toxic" % (percentage, label))


find_toxic_percentage(LABELS)
# Out:
# 100.00 % of toxic comments are toxic
# 100.00 % of severe_toxic comments are toxic
# 93.83 % of obscene comments are toxic
# 93.35 % of threat comments are toxic
# 93.59 % of insult comments are toxic
# 92.50 % of identity_hate comments are toxic

# %% [markdown]
# ### Adding in new features and examine their relationships with toxicness

# %%
def add_features(df):
    def count_caps_percentage(s):
        s = strip_punctuations(s, replace="")
        cnt = sum(1 for ch in s if ch.isupper())
        return 0 if cnt == 0 else int((cnt / len(s)) * 100)

    df["question_mark_count"] = df[COMMENT].apply(lambda s: s.count("?"))
    df["exclamation_mark_count"] = df[COMMENT].apply(lambda s: s.count("!"))
    df["caps_percentage"] = df[COMMENT].apply(count_caps_percentage)


def strip_punctuations_for_df(df):
    df[COMMENT] = df[COMMENT].apply(strip_punctuations)


add_features(train_df)

# %%
QUESTIONS = "question_mark_count"
EXCLAMATIONS = "exclamation_mark_count"
CAPS_PERCENTAGE = "caps_percentage"

FEATURES = [COMMENT, QUESTIONS, EXCLAMATIONS, CAPS_PERCENTAGE]

# %%
train_df.head()
# Out:
#                       id                                       comment_text  \
# 130060  b7bf5a6846bd456a  "\n Oppose. WP:MOSTM, the guideline covering t...
# 132921  c70efd55724be549            === I AM GLEN AND I LOVE BEING A FAG===
# 46589   7c7f688f129e511e  "\n\nIf it happens it may be worth noting but ...
# 129843  b68d08319e5fcb14        }}\n{{WikiProject Elections and Referendums
# 2528    06bf9f58011ca46a  "\n\nI posted a thread about Donny on WP:ANI  ...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate  \
# 130060      0             0        0       0       0              0
# 132921      1             0        0       0       0              0
# 46589       0             0        0       0       0              0
# 129843      0             0        0       0       0              0
# 2528        0             0        0       0       0              0
#
#         question_mark_count  exclamation_mark_count  caps_percentage
# 130060                    0                       0                8
# 132921                    0                       0              100
# 46589                     0                       0                3
# 129843                    0                       0               11
# 2528                      0                       0                5

# %%
def plot_relationship(df, features, target):
    step = 3
    for i in range(1, len(features)):
        feature = features[i]
        x, y = [], []
        for n in range(df[feature].min(), df[feature].max() + 1, step):
            x.append(n)
            criteria = (df[feature] >= n) & (df[feature] < n + step)
            cnt = df[criteria].size
            toxic_cnt = df[(criteria) & (df[target] == 1)].size
            y.append(toxic_cnt / cnt)
        plt.plot(x, y, "r-")
        plt.xlabel(feature)
        plt.ylabel("%s Percentage" % target)
        plt.xlim(
            0, min(250, df[feature].max())
        )  # set xlim to 250 so that plot for exclamation_count won't be too large
        plt.show()


plot_relationship(train_df, FEATURES, "toxic")
# Out:
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in long_scalars
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# From the plots we can tell that `question_mark_count` and `caps_percentage` can be used to tell if a comment is toxic or not. No general trend has been found between toxicness and `exclamation_mark_count`.

# %% [markdown]
# ### Cleaning Data

# %%
def transform_text(df):
    """
    Remove punctuations and stopwords from comment, and lemmatize words.
    """

    def clean(s, stop, lemmatizer):
        cleaned = [lemmatizer.lemmatize(w) for w in s.lower().split() if w not in stop]
        return " ".join(cleaned)

    cleaned_df = df.copy()
    strip_punctuations_for_df(cleaned_df)
    stop = stopwords.words("english")
    lemmatizer = WordNetLemmatizer()
    cleaned_df[COMMENT] = cleaned_df[COMMENT].apply(
        lambda s: clean(s, stop, lemmatizer)
    )
    return cleaned_df


cleaned_df = transform_text(train_df)

# %%
cleaned_df.head()
# Out:
#                       id                                       comment_text  \
# 130060  b7bf5a6846bd456a  oppose wpmostm guideline covering trademark br...
# 132921  c70efd55724be549                                      glen love fag
# 46589   7c7f688f129e511e  happens may worth noting present view like adv...
# 129843  b68d08319e5fcb14                    wikiproject election referendum
# 2528    06bf9f58011ca46a  posted thread donny wpani saturday 1 accused w...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate  \
# 130060      0             0        0       0       0              0
# 132921      1             0        0       0       0              0
# 46589       0             0        0       0       0              0
# 129843      0             0        0       0       0              0
# 2528        0             0        0       0       0              0
#
#         question_mark_count  exclamation_mark_count  caps_percentage
# 130060                    0                       0                8
# 132921                    0                       0              100
# 46589                     0                       0                3
# 129843                    0                       0               11
# 2528                      0                       0                5

# %% [markdown]
# ### Checking what words have highest frequenct in toxic comments using WordCloud

# %%
def generate_wordcloud(df, target):
    text = df[df[target] == 1][COMMENT]
    wordcloud = WordCloud(
        width=1000, height=700, background_color="white", stopwords=STOPWORDS
    ).generate(str(text))
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.title("Top Words for %s" % target)
    plt.show()


for label in LABELS:
    generate_wordcloud(cleaned_df, label)

# %% [markdown]
# ### Changing the comments into TF-IDF representation

# %%
vectorizer = TfidfVectorizer(
    ngram_range=(1, 2),
    tokenizer=lambda s: s.split(),
    min_df=3,
    max_df=0.9,
    strip_accents="unicode",
    use_idf=1,
    smooth_idf=1,
    sublinear_tf=1,
)


def get_term_vec(df, vectorizer, test=False):
    n = df.shape[0]
    if test:
        return vectorizer.transform(df[COMMENT])
    else:
        return vectorizer.fit_transform(df[COMMENT])

# %%
def preprocess(df, vec=False, test=False):
    add_features(df)
    df = transform_text(df)
    return df if not vec else get_term_vec(df, vectorizer, test)

# %%
train_vec = preprocess(train_df, vec=True, test=False)
valid_vec = preprocess(valid_df, vec=True, test=True)
test_vec = preprocess(test_df, vec=True, test=True)

# %% [markdown]
# ## Training Models
#
# We will use four models:
#
# Baseline: Naive-Bayes, Linear Regression
#
# Advanced: Random forest,
#
# ### Naive-Bayes Model with word vectors

# %%
def nb_predict(x, labels, test_x, test_df):
    preds = np.zeros((len(test_df), len(labels)))
    for i, target in enumerate(labels):
        print("predicting %s" % target)
        model = MultinomialNB()
        model.fit(x, train_df[target].values)
        preds[:, i] = model.predict(test_x).transpose()
    print()
    for i, target in enumerate(labels):
        mse = ((preds[:, i] - test_df[target]) ** 2).mean()
        score = metrics.accuracy_score(test_df[target], preds[:, i])
        print("%s: MSE = %f, Accuracy Score = %f" % (target, mse, score))
    return preds


nb_preds = nb_predict(train_vec, LABELS, valid_vec, valid_df)
# Out:
# predicting toxic
# predicting severe_toxic
# predicting obscene
# predicting threat
# predicting insult
# predicting identity_hate
#
# toxic: MSE = 0.075777, Accuracy Score = 0.924223
# severe_toxic: MSE = 0.010025, Accuracy Score = 0.989975
# obscene: MSE = 0.044376, Accuracy Score = 0.955624
# threat: MSE = 0.003300, Accuracy Score = 0.996700
# insult: MSE = 0.045701, Accuracy Score = 0.954299
# identity_hate: MSE = 0.008475, Accuracy Score = 0.991525

# %% [markdown]
# ## Logistic Rrgression Model with word vectors

# %% [markdown]
# ### Why Logistic regression: this is a very powerful model to classify data with two possible outcomes. It's fast and easy, works as a great entry point to explore the relationships between features and the target.

# %%
def lr_predict(x, labels, test_x, test_df, pen):
    preds = np.zeros((len(test_df), len(labels)))
    for i, target in enumerate(labels):
        print("Predicting %s" % target)
        model = LogisticRegression(penalty=pen)
        model.fit(x, train_df[target].values)
        preds[:,i] = model.predict(test_x).transpose()
    print()
    for i, target in enumerate(labels):
        mse = ((preds[:,i] - test_df[target]) **2).mean()
        score = metrics.accuracy_score(test_df[target], preds[:,i])
        print("%s: MSE = %f, Accuracy Score = %f" % (target, mse, score))
    return preds

# %%
lr_preds = lr_predict(train_vec, LABELS, valid_vec, valid_df, 'l2')
# Out:
# Predicting toxic
# Predicting severe_toxic
# Predicting obscene
# Predicting threat
# Predicting insult
# Predicting identity_hate
#
# toxic: MSE = 0.046151, Accuracy Score = 0.953849
# severe_toxic: MSE = 0.010000, Accuracy Score = 0.990000
# obscene: MSE = 0.023476, Accuracy Score = 0.976524
# threat: MSE = 0.003075, Accuracy Score = 0.996925
# insult: MSE = 0.030776, Accuracy Score = 0.969224
# identity_hate: MSE = 0.008000, Accuracy Score = 0.992000

# %%
def plot_mse(X, train_err, valid_err, name, target):
    plt.plot(X, train_err, "r-", label="training", marker="o")
    plt.plot(X, valid_err, "g-", label="validation", marker="o")
    plt.legend()
    plt.title("%s vs. MSE for %s" % (name, target))
    plt.xlabel(name)
    plt.ylabel("MSE")
    plt.show()

# %% [markdown]
# ### Tuning params for Logistic Regression

# %% [markdown]
# ### Change the penalty to L1 and see what it does to the model.

# %%
lr_preds = lr_predict(train_vec, LABELS, valid_vec, valid_df, 'l1')
# Out:
# Predicting toxic
# Predicting severe_toxic
# Predicting obscene
# Predicting threat
# Predicting insult
# Predicting identity_hate
#
# toxic: MSE = 0.041551, Accuracy Score = 0.958449
# severe_toxic: MSE = 0.010400, Accuracy Score = 0.989600
# obscene: MSE = 0.019150, Accuracy Score = 0.980850
# threat: MSE = 0.003325, Accuracy Score = 0.996675
# insult: MSE = 0.029076, Accuracy Score = 0.970924
# identity_hate: MSE = 0.007650, Accuracy Score = 0.992350

# %% [markdown]
# ## Result: slightly better than penalty=l2. So l1 fits the model better.

# %%
def tune_lr(c_values, X, train_df, X_val, valid_df, labels):
    def predict(clf, X, df, target):
        pred = clf.predict(X).transpose()
        mse = metrics.mean_squared_error(df[target], pred)
        return pred, mse

    preds, params = np.zeros((len(valid_df), len(labels))), {}
    for i, target in enumerate(labels):
        print("[%s] tuning C_value..." % target)
        y = train_df[target].values

        train_err, valid_err = [], []
        max_accuracy, best_c = 0.0, 0.0
        for cs in c_values:
            clf = LogisticRegression(C=cs, penalty='l1')
            clf.fit(X, y)
            _, train_mse = predict(clf, X, train_df, target)
            p, valid_mse = predict(clf, X_val, valid_df, target)
            train_err.append(train_mse)
            valid_err.append(valid_mse)

            score = metrics.accuracy_score(valid_df[target], p)
            if score > max_accuracy:
                preds[:, i] = p
                max_accuracy = score
                best_c = cs
        params[target] = {"c_value": best_c, "accuracy": max_accuracy}
        plot_mse(c_values, train_err, valid_err, "Alpha", target)
    return preds, params

c_values = [0.001, 0.01, 0.8, 1, 5, 10, 20, 30, 40, 50, 70, 100]
_, nb_params = tune_lr(c_values, train_vec, train_df, valid_vec, valid_df, LABELS)
nb_params
# Out:
# [toxic] tuning C_value...
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [severe_toxic] tuning C_value...
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [obscene] tuning C_value...
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [threat] tuning C_value...
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [insult] tuning C_value...
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [identity_hate] tuning C_value...
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/aiden/softwares/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# {'toxic': {'c_value': 5, 'accuracy': 0.9594739868496712},
#  'severe_toxic': {'c_value': 0.001, 'accuracy': 0.9899497487437185},
#  'obscene': {'c_value': 1, 'accuracy': 0.9808495212380309},
#  'threat': {'c_value': 70, 'accuracy': 0.9970499262481562},
#  'insult': {'c_value': 1, 'accuracy': 0.9709242731068277},
#  'identity_hate': {'c_value': 1, 'accuracy': 0.9923498087452186}}

# %% [markdown]
# # Random Forest

# %% [markdown]
#     ## Why RF:
